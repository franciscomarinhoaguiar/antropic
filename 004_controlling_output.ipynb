# %%
#Load env variables
from dotenv import load_dotenv
load_dotenv()

# %%
#Create an api client
from anthropic import Anthropic
from Util import Util

client = Anthropic()
model = "claude-sonnet-4-0"

u = Util(client, model)

# %%
messages = []
u.add_user_message(messages, "generate a very short event bridge rule as json")
u.add_assistant_message(messages, "```json")


u.chat(messages, stopSequence=["```"])
