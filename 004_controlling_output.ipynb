# %%
#Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Create an api client
from anthropic import Anthropic
from Util import Util

client = Anthropic()
model = "claude-sonnet-4-0"

u = Util(client, model)

# %%
messages = []
u.add_user_message(messages, "generate a very short event bridge rule as json")
u.add_assistant_message(messages, "```json")


text = u.chat(messages, stop_sequences=["```"])

# %%
print(text)
# Out:
# {
#   "Name": "OrderProcessingRule",
#   "EventPattern": {
#     "source": ["myapp.orders"],
#     "detail-type": ["Order Placed"]
#   },
#   "Targets": [
#     {
#       "Id": "1",
#       "Arn": "arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder"
#     }
#   ]
# }

# %%
import json

# %%
# Clean up and parse the JSON
clean_json = json.loads(text.strip())

# %%
print(clean_json)
# Out:
# {'Name': 'OrderProcessingRule', 'EventPattern': {'source': ['myapp.orders'], 'detail-type': ['Order Placed']}, 'Targets': [{'Id': '1', 'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder'}]}

# %% [markdown]
# Exercise

# %%
messages = []
prompt = """
Generate three different sample aws cli commands. Each should be very short.
"""
u.add_user_message(messages, prompt)
u.add_assistant_message(messages,"```bash")


answer = u.chat(messages,stop_sequences=["```bash"])

answer
# Out:
# '\n# List all S3 buckets\naws s3 ls\n\n# Get EC2 instance information\naws ec2 describe-instances\n\n# Create a new IAM user\naws iam create-user --user-name john\n```'
